# %% [markdown]
# # Install/Setup

# %%
# Setup
# !git clone --branch=master https://github.com/kunato/mt3-pytorch.git
# !python3 -m pip install torch transformers==4.18.0 librosa==0.9.1 

# !python -m pip install tensorflow

# !python -m pip install ddsp

# !python -m pip install t5==0.9.3 note-seq==0.0.3 pretty-midi==0.2.9 einops==0.4.1

# !python -m pip install omegaconf

# !python -m pip install pytorch_lightning

# !python -m pip install immutabledict
# Out:
# Cloning into 'mt3-pytorch'...
# remote: Enumerating objects: 99, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 99 (delta 3), reused 1 (delta 1), pack-reused 91
# Unpacking objects: 100% (99/99), 43.82 KiB | 1.18 MiB/s, done.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 37.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.1/213.1 kB 21.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 22.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 68.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 kB 52.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 93.8 MB/s eta 0:00:00
# ...

# %%
# !pwd
# %cd mt3-pytorch/
from google.colab import files
uploaded = files.upload()
# !unzip data.zip

# %%
# Imports

import json
import math
import os
from typing import List

import numpy as np
import transformers
from tqdm import tqdm
from models.t5 import T5ForConditionalGeneration, T5Config
import torch.nn as nn
import torch
import librosa
from contrib import spectrograms, vocabularies, note_sequences, metrics_utils
import note_seq

# %% [markdown]
# # Training

# %%
# !python mt3_net.py
# Out:
# 2023-04-13 02:02:51.255232: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Global seed set to 365
# Config config/config.yaml
# Creating:  ./results/016
# MT3Net(
#   (model): T5ForConditionalGeneration(
#     (proj): Linear(in_features=512, out_features=512, bias=False)
#     (decoder_embed_tokens): Embedding(1536, 512)
#     (encoder): T5Stack(
#       (embed_tokens): Linear(in_features=512, out_features=512, bias=False)
#       (pos_emb): FixedPositionalEmbedding()
#       (block): ModuleList(
#         (0-7): 8 x T5Block(
#           (layer): ModuleList(
#             (0): T5LayerSelfAttention(
#               (SelfAttention): T5Attention(
#                 (q): Linear(in_features=512, out_features=384, bias=False)
#                 (k): Linear(in_features=512, out_features=384, bias=False)
#                 (v): Linear(in_features=512, out_features=384, bias=False)
# ...

# %%
# !zip -r /content/file.zip /content/mt3-pytorch/
files.download("/content/file.zip")
# Out:
#   adding: content/mt3-pytorch/ (stored 0%)
#   adding: content/mt3-pytorch/contrib/ (stored 0%)
#   adding: content/mt3-pytorch/contrib/spectrograms.py (deflated 58%)
#   adding: content/mt3-pytorch/contrib/__init__.py (stored 0%)
#   adding: content/mt3-pytorch/contrib/note_sequences.py (deflated 78%)
#   adding: content/mt3-pytorch/contrib/__pycache__/ (stored 0%)
#   adding: content/mt3-pytorch/contrib/__pycache__/note_sequences.cpython-39.pyc (deflated 59%)
#   adding: content/mt3-pytorch/contrib/__pycache__/spectrograms.cpython-39.pyc (deflated 44%)
#   adding: content/mt3-pytorch/contrib/__pycache__/preprocessor.cpython-39.pyc (deflated 41%)
#   adding: content/mt3-pytorch/contrib/__pycache__/event_codec.cpython-39.pyc (deflated 51%)
#   adding: content/mt3-pytorch/contrib/__pycache__/vocabularies.cpython-39.pyc (deflated 53%)
#   adding: content/mt3-pytorch/contrib/__pycache__/__init__.cpython-39.pyc (deflated 28%)
# ...
